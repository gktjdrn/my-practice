# %% [markdown]
# <a href="https://colab.research.google.com/github/gktjdrn/my-practice/blob/main/%EC%8B%9D%EB%B3%B42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def combination():
  import random
  money = 1000000
  print('############ 식보 게임 ############')
  while True:
    a = random.randint(1,6)
    b = random.randint(1,6)
    c = random.randint(1,6)
    d = [a,b,c]
    if money == 0:
      print('파산하셨습니다.')
      break
    answer = input("게임을 진행하시겠습니까('y' or 'n')")
    if answer == 'n':
      break
    elif answer  == 'y':
      print(f"당신의 돈: {money}원")
      while True:
        e = int(input('베팅금을 입력해주세요'))
        if e <= money:
          break
        else:
          print("베팅금이 당신의 돈보다 많습니다.")
      f = e
      money -= e
      while True: 
        g,h = input("주사위를 돌려 나올 수 2개를 예측해주세요").split()
        g = int(g)
        h = int(h)
        if 1 <= g <= 6 and 1 <= h <= 6:
          break
        else:
          print("잘못 입력하셨습니다. 다시 입력해주세요")
      print(f"당신의 수: {g}, {h} 주사위의 수: {a}, {b}, {c}")
      if g in d:
        d.remove(g)
      if h in d:
        d.remove(h)
      if len(d) == 1:
        print('성공')
        e *= 3
        print(f'얻은 금액은 {e - f}원입니다.')
        money += e
      else:
        print('실패')
        print(f'잃은 금액은 {e}원입니다')
      print(f"당신의 돈: {money}원")
def single():
  import random
  money = 1000000
  print('############ 식보 게임 ############')
  while True:
    a = random.randint(1,6)
    b = random.randint(1,6)
    c = random.randint(1,6)
    d = [a,b,c]
    if money == 0:
      print('파산하셨습니다.')
      break
    answer = input("게임을 진행하시겠습니까('y' or 'n')")
    if answer == 'n':
      break
    elif answer  == 'y':
      print(f"당신의 돈: {money}원")
      while True:
        e = int(input('베팅금을 입력해주세요'))
        if e <= money:
          break
        else:
          print("베팅금이 당신의 돈보다 많습니다.")
      f = e
      money -= e
      while True:
        g,h,i = input("주사위를 돌려 나올 수 3개를 예측해주세요").split()
        g = int(g)
        h = int(h)
        i = int(i)
        if 1 <= g <= 6 and 1 <= h <= 6 and 1 <= i <= 6:
          break
        else:
          print("잘못 입력하셨습니다. 다시 입력해주세요")
      print(f"당신의 수: {g}, {h}, {i} 주사위의 수: {a}, {b}, {c}")
      if g in d:
        d.remove(g)
      if h in d:
        d.remove(h)
      if i in d:
        d.remove(i)
      if len(d) == 0:
        print('3개')
        e *= 12
        print(f'얻은 금액은 {e - f}원입니다.')
        money += e
      elif len(d) == 1:
        print('두개')
        e *= 2
        print(f'얻은 금액은 {e - f}원 입니다.')
        money += e
      elif len(d) == 2:
        print('한개')
        print('원금을 돌려받으셨습니다.')
        money+=e
      else:
        print('실패')
        print(f'잃은 금액은 {e}원 입니다.')
      print(f"당신의 돈: {money}원")

def total():
  import random
  money = 1000000
  print('############ 식보 게임 ############')
  while True:
    a = random.randint(1,6)
    b = random.randint(1,6)
    c = random.randint(1,6)
    d = [a,b,c]
    if money == 0:
      print('파산하셨습니다.')
      break
    answer = input("게임을 진행하시겠습니까('y' or 'n')")
    if answer == 'n':
      break
    elif answer  == 'y':
      print(f"당신의 돈: {money}원")
      while True:
        e = int(input('베팅금을 입력해주세요'))
        if e <= money:
          break
        else:
          print("베팅금이 당신의 돈보다 많습니다.")
      f = e
      money -= e
      while True:
        g = int(input("주사위를 돌려 나올 수의 합계를 예측해주세요 범위:3 ~ 18"))
        if 3 <= g <= 18:
          break
        else:
          print("잘못 입력하셨습니다 다시 입력해주세요.")
      print(f'주사위의 눈: {a}, {b}, {c}, 주사위 합계: {sum(d)}, 당신의 예측: {g}')
      if sum(d) == g:
        print('성공')
        e *= 7
        print(f"얻은 금액은 {e - f}원입니다.")
        money += e
      else:
        print('실패')
        print(f"잃은 금액은 {e}원입니다.")
      print(f"당신의 돈: {money}원")

def double():
  import random
  money = 1000000
  print('############ 식보 게임 ############')
  while True:
    a = random.randint(1,6)
    b = random.randint(1,6)
    c = random.randint(1,6)
    d = [a,b,c]
    if money == 0:
      print('파산하셨습니다.')
      break
    answer = input("게임을 진행하시겠습니까('y' or 'n')")
    if answer == 'n':
      break
    elif answer  == 'y':
      print(f"당신의 돈: {money}원")
      while True:
        e = int(input('베팅금을 입력해주세요'))
        if e <= money:
          break
        else:
          print("베팅금이 당신의 돈보다 많습니다.")
      f = e
      money -= e
      while True:
        print(f'주사위의 눈: {a}, {b}, {c}')
        if a == b:
          print('성공')
          e *= 10
          print(f'얻은 금액은 {e - f}원입니다.')
          money += e
        elif a == c:
          print('성공')
          e *= 10
          print(f'얻은 금액은 {e - f}원입니다.')
          money += e
        elif b == c:
          print('성공')
          e *= 10
          print(f'얻은 금액은 {e - f}원입니다.')
          money += e
        else:
          print('실패')
          print(f'잃은 금액은 {e}원입니다.')
        break

def triple():
  import random
  money = 1000000
  print('############ 식보 게임 ############')
  while True:
    a = random.randint(1,6)
    b = random.randint(1,6)
    c = random.randint(1,6)
    d = [a,b,c]
    if money == 0:
      print('파산하셨습니다.')
      break
    answer = input("게임을 진행하시겠습니까('y' or 'n')")
    if answer == 'n':
      break
    elif answer  == 'y':
      print(f"당신의 돈: {money}원")
      while True:
        e = int(input('베팅금을 입력해주세요'))
        if e <= money:
          break
        else:
          print("베팅금이 당신의 돈보다 많습니다.")
      f = e
      money -= e
      print(f'주사위의 눈: {a}, {b}, {c}')
      if a == b == c:
        print("성공")
        e *= 30
        print(f'얻은 금액은 {e - f}원입니다.')
        money += e
      else:
        print("실패")
        print(f'잃은 금액은 {e}원입니다.')
      print(f"당신의 돈: {money}원")

def bigsmall():
  import random
  money = 1000000
  print('############ 식보 게임 ############')
  while True:
    a = random.randint(1,6)
    b = random.randint(1,6)
    c = random.randint(1,6)
    d = [a,b,c]
    if money == 0:
      print('파산하셨습니다.')
      break
    answer = input("게임을 진행하시겠습니까('y' or 'n')")
    if answer == 'n':
      break
    elif answer  == 'y':
      print(f"당신의 돈: {money}원")
      while True:
        e = int(input('베팅금을 입력해주세요'))
        if e <= money:
          break
        else:
          print("베팅금이 당신의 돈보다 많습니다.")
      f = e
      money -= e
      while True:
        g = input("베팅해주세요('빅' or '스몰')")
        if g == '빅' or g == '스몰':
          break
        else:
          print('잘못 입력하셨습니다. 다시 입력해주세요')
      if g == '스몰':
        h = list(range(4,11))
        print(f'당신의 예측: 4 ~ 10 주사위의 눈: {a}, {b}, {c} 주사위 합계: {sum(d)}')
        if sum(d) in h:
          print('성공')
          e *= 2
          print(f'얻은 금액은 {e - f}원입니다.')
          money += e
        else:
          print('실패')
          print(f'잃은 금액은 {e}원입니다.')
      elif g == '빅':
        h = list(range(11,18))
        print(f'당신의 예측: 11 ~ 17 주사위의 눈: {a}, {b}, {c} 주사위 합계: {sum(d)}')
        if sum(d) in h:
          print('성공')
          e *= 2
          print(f'얻은 금액은 {e - f}원입니다.')
          money += e
        else:
          print('실패')
          print(f'잃은 금액은 {e}원입니다.')
      print(f"당신의 돈: {money}원")
    else:
      print('잘못 입력하셨습니다. 다시 입력해주세요')
